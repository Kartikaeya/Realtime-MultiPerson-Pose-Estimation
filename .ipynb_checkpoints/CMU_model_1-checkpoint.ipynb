# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import cv2
import numpy as np
from matplotlib import pyplot as plt
from torchsummary import summary
from ipynb.fs.full.Preprocess_Image import preprocess_image_for_inference

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.model0 = self.get_vgg()
        
        self.model1_1 = self.get_layer_1(38)
        self.model2_1 = self.get_layer_T(38)
        self.model3_1 = self.get_layer_T(38)
        self.model4_1 = self.get_layer_T(38)
        self.model5_1 = self.get_layer_T(38)
        self.model6_1 = self.get_layer_T(38)
        
        self.model1_2 = self.get_layer_1(19)
        self.model2_2 = self.get_layer_T(19)
        self.model3_2 = self.get_layer_T(19)
        self.model4_2 = self.get_layer_T(19)
        self.model5_2 = self.get_layer_T(19)
        self.model6_2 = self.get_layer_T(19)
        
    def forward(self, x):
        x_vgg = self.model0(x)
        
        layer1_paf = self.model1_1(x_vgg)
        layer1_confidence_map = self.model1_2(x_vgg)
        concat = torch.cat([layer1_paf, layer1_confidence_map, x_vgg], 1)
        
        layer2_paf = self.model2_1(concat)
        
        layer2_confidence_map = self.model2_2(concat)
        concat = torch.cat([layer2_paf, layer2_confidence_map, x_vgg], 1)
        
        layer3_paf = self.model3_1(concat)
        layer3_confidence_map = self.model3_2(concat)
        concat = torch.cat([layer3_paf, layer3_confidence_map, x_vgg], 1)
        
        layer4_paf = self.model4_1(concat)
        layer4_confidence_map = self.model4_2(concat)
        concat = torch.cat([layer4_paf, layer4_confidence_map, x_vgg], 1)
        
        layer5_paf = self.model5_1(concat)
        layer5_confidence_map = self.model5_2(concat)
        concat = torch.cat([layer5_paf, layer5_confidence_map, x_vgg], 1)
        
        layer6_paf = self.model6_1(concat)
        layer6_confidence_map = self.model6_2(concat)
        
        return layer6_paf, layer6_confidence_map
    def get_vgg(self):
        vgg_model = nn.Sequential(nn.Conv2d(3, 64, 3, 1, 1),
                                nn.ReLU(),
                                nn.Conv2d(64, 64, 3, 1, 1),
                                nn.ReLU(),
                                nn.MaxPool2d(2, 2, 0),
                                nn.Conv2d(64, 128, 3, 1, 1),
                                nn.ReLU(),
                                nn.Conv2d(128, 128, 3, 1, 1),
                                nn.ReLU(),
                                nn.MaxPool2d(2, 2, 0),
                                nn.Conv2d(128, 256, 3, 1, 1),
                                nn.ReLU(),
                                nn.Conv2d(256, 256, 3, 1, 1),
                                nn.ReLU(),
                                nn.Conv2d(256, 256, 3, 1, 1),
                                nn.ReLU(),
                                nn.Conv2d(256, 256, 3, 1, 1),
                                nn.ReLU(),
                                nn.MaxPool2d(2, 2, 0),
                                nn.Conv2d(256, 512, 3, 1, 1),
                                nn.ReLU(),
                                nn.Conv2d(512, 512, 3, 1, 1),
                                nn.ReLU(),
                                nn.Conv2d(512, 256, 3, 1, 1),
                                nn.ReLU(),
                                nn.Conv2d(256, 128, 3, 1, 1),
                                nn.ReLU())
        return vgg_model
    def get_layer_1(self, num_last_layer_channel):
        first_layer_model = nn.Sequential(nn.Conv2d(128, 128, 3 ,1 ,1),
                                          nn.ReLU(),
                                          nn.Conv2d(128, 128, 3 ,1 ,1),
                                          nn.ReLU(),
                                          nn.Conv2d(128, 128, 3 ,1 ,1),
                                          nn.ReLU(),
                                          nn.Conv2d(128, 512, 1 ,1 ,0),
                                          nn.ReLU(),
                                          nn.Conv2d(512, num_last_layer_channel, 1 ,1 ,0),
                                          nn.ReLU())
        return first_layer_model

    def get_layer_T(self, num_last_layer_channel):
        layer_T = nn.Sequential(nn.Conv2d(185, 128, 7 ,1 ,3),
                                nn.ReLU(),
                                nn.Conv2d(128, 128, 7 ,1 ,3),
                                nn.ReLU(),
                                nn.Conv2d(128, 128, 7 ,1 ,3),
                                nn.ReLU(),
                                nn.Conv2d(128, 128, 7 ,1 ,3),
                                nn.ReLU(),
                                nn.Conv2d(128, 128, 7 ,1 ,3),
                                nn.ReLU(),
                                nn.Conv2d(128, 128, 1 ,1 ,0),
                                nn.ReLU(),
                                nn.Conv2d(128, num_last_layer_channel, 1 ,1 ,0),
                                nn.ReLU())
        return layer_T

# %%
model = Net()
model.cuda()
# print(model)
# summary(model, (3, 122, 122))
print("Model's state dictionary : ")
for model_param_name , value in model.state_dict().items():
    print(model_param_name , "\t", value.shape)
# Out:
# Model's state dictionary :
# model0.0.weight 	 torch.Size([64, 3, 3, 3])
# model0.0.bias 	 torch.Size([64])
# model0.2.weight 	 torch.Size([64, 64, 3, 3])
# model0.2.bias 	 torch.Size([64])
# model0.5.weight 	 torch.Size([128, 64, 3, 3])
# model0.5.bias 	 torch.Size([128])
# model0.7.weight 	 torch.Size([128, 128, 3, 3])
# model0.7.bias 	 torch.Size([128])
# model0.10.weight 	 torch.Size([256, 128, 3, 3])
# model0.10.bias 	 torch.Size([256])
# model0.12.weight 	 torch.Size([256, 256, 3, 3])
# model0.12.bias 	 torch.Size([256])
# model0.14.weight 	 torch.Size([256, 256, 3, 3])
# model0.14.bias 	 torch.Size([256])
# model0.16.weight 	 torch.Size([256, 256, 3, 3])
# model0.16.bias 	 torch.Size([256])
# model0.19.weight 	 torch.Size([512, 256, 3, 3])
# model0.19.bias 	 torch.Size([512])
# model0.21.weight 	 torch.Size([512, 512, 3, 3])
# model0.21.bias 	 torch.Size([512])
# model0.23.weight 	 torch.Size([256, 512, 3, 3])
# model0.23.bias 	 torch.Size([256])
# model0.25.weight 	 torch.Size([128, 256, 3, 3])
# model0.25.bias 	 torch.Size([128])
# model1_1.0.weight 	 torch.Size([128, 128, 3, 3])
# model1_1.0.bias 	 torch.Size([128])
# model1_1.2.weight 	 torch.Size([128, 128, 3, 3])
# model1_1.2.bias 	 torch.Size([128])
# model1_1.4.weight 	 torch.Size([128, 128, 3, 3])
# model1_1.4.bias 	 torch.Size([128])
# model1_1.6.weight 	 torch.Size([512, 128, 1, 1])
# model1_1.6.bias 	 torch.Size([512])
# model1_1.8.weight 	 torch.Size([38, 512, 1, 1])
# model1_1.8.bias 	 torch.Size([38])
# model2_1.0.weight 	 torch.Size([128, 185, 7, 7])
# model2_1.0.bias 	 torch.Size([128])
# model2_1.2.weight 	 torch.Size([128, 128, 7, 7])
# model2_1.2.bias 	 torch.Size([128])
# model2_1.4.weight 	 torch.Size([128, 128, 7, 7])
# model2_1.4.bias 	 torch.Size([128])
# model2_1.6.weight 	 torch.Size([128, 128, 7, 7])
# model2_1.6.bias 	 torch.Size([128])
# model2_1.8.weight 	 torch.Size([128, 128, 7, 7])
# model2_1.8.bias 	 torch.Size([128])
# model2_1.10.weight 	 torch.Size([128, 128, 1, 1])
# model2_1.10.bias 	 torch.Size([128])
# model2_1.12.weight 	 torch.Size([38, 128, 1, 1])
# model2_1.12.bias 	 torch.Size([38])
# model3_1.0.weight 	 torch.Size([128, 185, 7, 7])
# model3_1.0.bias 	 torch.Size([128])
# model3_1.2.weight 	 torch.Size([128, 128, 7, 7])
# model3_1.2.bias 	 torch.Size([128])
# model3_1.4.weight 	 torch.Size([128, 128, 7, 7])
# model3_1.4.bias 	 torch.Size([128])
# model3_1.6.weight 	 torch.Size([128, 128, 7, 7])
# model3_1.6.bias 	 torch.Size([128])
# model3_1.8.weight 	 torch.Size([128, 128, 7, 7])
# model3_1.8.bias 	 torch.Size([128])
# model3_1.10.weight 	 torch.Size([128, 128, 1, 1])
# model3_1.10.bias 	 torch.Size([128])
# model3_1.12.weight 	 torch.Size([38, 128, 1, 1])
# model3_1.12.bias 	 torch.Size([38])
# model4_1.0.weight 	 torch.Size([128, 185, 7, 7])
# model4_1.0.bias 	 torch.Size([128])
# model4_1.2.weight 	 torch.Size([128, 128, 7, 7])
# model4_1.2.bias 	 torch.Size([128])
# model4_1.4.weight 	 torch.Size([128, 128, 7, 7])
# model4_1.4.bias 	 torch.Size([128])
# model4_1.6.weight 	 torch.Size([128, 128, 7, 7])
# model4_1.6.bias 	 torch.Size([128])
# model4_1.8.weight 	 torch.Size([128, 128, 7, 7])
# model4_1.8.bias 	 torch.Size([128])
# model4_1.10.weight 	 torch.Size([128, 128, 1, 1])
# model4_1.10.bias 	 torch.Size([128])
# model4_1.12.weight 	 torch.Size([38, 128, 1, 1])
# model4_1.12.bias 	 torch.Size([38])
# model5_1.0.weight 	 torch.Size([128, 185, 7, 7])
# model5_1.0.bias 	 torch.Size([128])
# model5_1.2.weight 	 torch.Size([128, 128, 7, 7])
# model5_1.2.bias 	 torch.Size([128])
# model5_1.4.weight 	 torch.Size([128, 128, 7, 7])
# model5_1.4.bias 	 torch.Size([128])
# model5_1.6.weight 	 torch.Size([128, 128, 7, 7])
# model5_1.6.bias 	 torch.Size([128])
# model5_1.8.weight 	 torch.Size([128, 128, 7, 7])
# model5_1.8.bias 	 torch.Size([128])
# model5_1.10.weight 	 torch.Size([128, 128, 1, 1])
# model5_1.10.bias 	 torch.Size([128])
# model5_1.12.weight 	 torch.Size([38, 128, 1, 1])
# model5_1.12.bias 	 torch.Size([38])
# model6_1.0.weight 	 torch.Size([128, 185, 7, 7])
# model6_1.0.bias 	 torch.Size([128])
# model6_1.2.weight 	 torch.Size([128, 128, 7, 7])
# model6_1.2.bias 	 torch.Size([128])
# model6_1.4.weight 	 torch.Size([128, 128, 7, 7])
# model6_1.4.bias 	 torch.Size([128])
# model6_1.6.weight 	 torch.Size([128, 128, 7, 7])
# model6_1.6.bias 	 torch.Size([128])
# model6_1.8.weight 	 torch.Size([128, 128, 7, 7])
# model6_1.8.bias 	 torch.Size([128])
# model6_1.10.weight 	 torch.Size([128, 128, 1, 1])
# model6_1.10.bias 	 torch.Size([128])
# model6_1.12.weight 	 torch.Size([38, 128, 1, 1])
# model6_1.12.bias 	 torch.Size([38])
# model1_2.0.weight 	 torch.Size([128, 128, 3, 3])
# model1_2.0.bias 	 torch.Size([128])
# model1_2.2.weight 	 torch.Size([128, 128, 3, 3])
# model1_2.2.bias 	 torch.Size([128])
# model1_2.4.weight 	 torch.Size([128, 128, 3, 3])
# model1_2.4.bias 	 torch.Size([128])
# model1_2.6.weight 	 torch.Size([512, 128, 1, 1])
# model1_2.6.bias 	 torch.Size([512])
# model1_2.8.weight 	 torch.Size([19, 512, 1, 1])
# model1_2.8.bias 	 torch.Size([19])
# model2_2.0.weight 	 torch.Size([128, 185, 7, 7])
# model2_2.0.bias 	 torch.Size([128])
# model2_2.2.weight 	 torch.Size([128, 128, 7, 7])
# model2_2.2.bias 	 torch.Size([128])
# model2_2.4.weight 	 torch.Size([128, 128, 7, 7])
# model2_2.4.bias 	 torch.Size([128])
# model2_2.6.weight 	 torch.Size([128, 128, 7, 7])
# model2_2.6.bias 	 torch.Size([128])
# model2_2.8.weight 	 torch.Size([128, 128, 7, 7])
# model2_2.8.bias 	 torch.Size([128])
# model2_2.10.weight 	 torch.Size([128, 128, 1, 1])
# model2_2.10.bias 	 torch.Size([128])
# model2_2.12.weight 	 torch.Size([19, 128, 1, 1])
# model2_2.12.bias 	 torch.Size([19])
# model3_2.0.weight 	 torch.Size([128, 185, 7, 7])
# model3_2.0.bias 	 torch.Size([128])
# model3_2.2.weight 	 torch.Size([128, 128, 7, 7])
# model3_2.2.bias 	 torch.Size([128])
# model3_2.4.weight 	 torch.Size([128, 128, 7, 7])
# model3_2.4.bias 	 torch.Size([128])
# model3_2.6.weight 	 torch.Size([128, 128, 7, 7])
# model3_2.6.bias 	 torch.Size([128])
# model3_2.8.weight 	 torch.Size([128, 128, 7, 7])
# model3_2.8.bias 	 torch.Size([128])
# model3_2.10.weight 	 torch.Size([128, 128, 1, 1])
# model3_2.10.bias 	 torch.Size([128])
# model3_2.12.weight 	 torch.Size([19, 128, 1, 1])
# model3_2.12.bias 	 torch.Size([19])
# model4_2.0.weight 	 torch.Size([128, 185, 7, 7])
# model4_2.0.bias 	 torch.Size([128])
# model4_2.2.weight 	 torch.Size([128, 128, 7, 7])
# model4_2.2.bias 	 torch.Size([128])
# model4_2.4.weight 	 torch.Size([128, 128, 7, 7])
# model4_2.4.bias 	 torch.Size([128])
# model4_2.6.weight 	 torch.Size([128, 128, 7, 7])
# model4_2.6.bias 	 torch.Size([128])
# model4_2.8.weight 	 torch.Size([128, 128, 7, 7])
# model4_2.8.bias 	 torch.Size([128])
# model4_2.10.weight 	 torch.Size([128, 128, 1, 1])
# model4_2.10.bias 	 torch.Size([128])
# model4_2.12.weight 	 torch.Size([19, 128, 1, 1])
# model4_2.12.bias 	 torch.Size([19])
# model5_2.0.weight 	 torch.Size([128, 185, 7, 7])
# model5_2.0.bias 	 torch.Size([128])
# model5_2.2.weight 	 torch.Size([128, 128, 7, 7])
# model5_2.2.bias 	 torch.Size([128])
# model5_2.4.weight 	 torch.Size([128, 128, 7, 7])
# model5_2.4.bias 	 torch.Size([128])
# model5_2.6.weight 	 torch.Size([128, 128, 7, 7])
# model5_2.6.bias 	 torch.Size([128])
# model5_2.8.weight 	 torch.Size([128, 128, 7, 7])
# model5_2.8.bias 	 torch.Size([128])
# model5_2.10.weight 	 torch.Size([128, 128, 1, 1])
# model5_2.10.bias 	 torch.Size([128])
# model5_2.12.weight 	 torch.Size([19, 128, 1, 1])
# model5_2.12.bias 	 torch.Size([19])
# model6_2.0.weight 	 torch.Size([128, 185, 7, 7])
# model6_2.0.bias 	 torch.Size([128])
# model6_2.2.weight 	 torch.Size([128, 128, 7, 7])
# model6_2.2.bias 	 torch.Size([128])
# model6_2.4.weight 	 torch.Size([128, 128, 7, 7])
# model6_2.4.bias 	 torch.Size([128])
# model6_2.6.weight 	 torch.Size([128, 128, 7, 7])
# model6_2.6.bias 	 torch.Size([128])
# model6_2.8.weight 	 torch.Size([128, 128, 7, 7])
# model6_2.8.bias 	 torch.Size([128])
# model6_2.10.weight 	 torch.Size([128, 128, 1, 1])
# model6_2.10.bias 	 torch.Size([128])
# model6_2.12.weight 	 torch.Size([19, 128, 1, 1])
# model6_2.12.bias 	 torch.Size([19])

# %%
model.load_state_dict(torch.load('pose_model.pth'))
# Out:
# <All keys matched successfully>

# %%
model.eval()
# test_tensor = torch.rand((1, 3, 674, 712))
# test_tensor = test_tensor.cuda()
# paf , confidence_map = model(test_tensor)
img = cv2.imread('images/self.jpg')
img_processed = preprocess_image_for_inference(img)
# img = img.cpu()
# plt.imshow((np.transpose(np.squeeze(img), (1, 2 ,0))*255)[:, :, [2, 1, 0]])
# plt.show()
paf , confidence_map = model(img_processed)

# %%
confidence_map.shape
con_np = confidence_map.cpu()
con_np = con_np.detach().numpy()
con_np.shape
# Out:
# (1, 19, 62, 46)

# %%
plt.imshow(cv2.resize(img, (con_np.shape[3], con_np.shape[2]))[:, :, [2,1,0]])
plt.imshow(np.squeeze(con_np)[19], alpha = 0.5)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-112-4fed3a296903> in <module>
#       1 plt.imshow(cv2.resize(img, (con_np.shape[3], con_np.shape[2]))[:, :, [2,1,0]])
# ----> 2 plt.imshow(np.squeeze(con_np)[19], alpha = 0.5)
#
# IndexError: index 19 is out of bounds for axis 0 with size 19
